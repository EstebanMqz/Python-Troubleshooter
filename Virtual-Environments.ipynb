# %% [markdown]
# <h3><div align="center"><font color= '#318f17'><b> Subprocess Virtual Environment </b></font></div></h3>
#
# [![subprocess](https://img.shields.io/badge/subprocess-builtin_module-black?style=flat)](https://docs.python.org/3/library/subprocess.html)
#
# - Built-in module that generates processes from terminals <i>([cmd](https://en.wikipedia.org/wiki/Cmd.exe), [bash](https://github.com/EstebanMqz/Git-Basic-Commands), [powershell](https://learn.microsoft.com/en-us/powershell/)) </i> , connects to their [input,output & error pipes](https://docs.python.org/3/library/subprocess.html#subprocess.Popen) while returning their respective [output codes](https://docs.python.org/3/library/subprocess.html#subprocess.CompletedProcess) <i>(0: success, 1: error, 2: warning).</i>
# - It <i>can</i> be used to create a [venv](https://docs.python.org/3/library/subprocess.html) with the arg. in a sequence of strings.
# - It <i>can</i> be used to install, update or uninstall modules using [pkg managers](https://en.wikipedia.org/wiki/Package_manager):<br>
# [`pip`](https://pypi.org/project/pip/), [`conda`](https://docs.conda.io/en/latest/), [`easy_install`](https://setuptools.pypa.io/en/latest/), [`poetry`](https://python-poetry.org/docs/), [`pipenv`](https://pipenv.pypa.io/en/latest/), [`virtualenv`](https://virtualenv.pypa.io/en/latest/), [`venv`](https://docs.python.org/3/library/venv.html), [`conda-forge`](https://conda-forge.org/docs/) but it's used for gral. command running purposes.
# - [`subprocess`](https://docs.python.org/3/library/subprocess.html) is considered <i>lower-level</i> because of its manual config., but has more control over processes. <br>

# %% [markdown]
# It's recommended to use any of the latest Python **stable** versions which are those with latest release dates but also in a <b>maintenance mode</b> of `bug fix` (for an improved performance) or `security` (focused to reduce vulnerabilities), nevertheless, it can't be assumed that one is better than the other.

# %%
import subprocess , io, json

def python_versions(manager, venv_name):
    {"""Function to get Python versions & release dates from Python.org/downloads.

    Parameters:
    ----------
    + manager: str
        Package manager to use for Python versions & release dates.
    + venv_name: str
        Virtual environment name for the given Python version passed as input to be installed for.
    Returns:
    -------
    + Python versions & release dates: dict
        Python versions & release dates from Python.org/downloads.
    """}

    subprocess.run([manager, "install", "beautifulsoup4", "requests"])
    from bs4 import BeautifulSoup
    import requests
    
    url = 'https://www.python.org/downloads/'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    releases = soup.select('.download-list-widget .list-row-container li')

    versions, output = {}, io.StringIO()    
    for i, release in enumerate(releases):
        version = release.select_one('.release-number').text.strip()
        date = release.select_one('.release-date').text.strip()
        versions[i+1] = {'version': version, 'date': date}
        print(f"{i+1} version: {date} {versions[i+1]['version']}", file=output)  
    print(output.getvalue())  
    
    i = input("Enter the n* version number to retrieve:")
    version_to_install = versions[int(i)]['version']
    return version_to_install  

version = python_versions("pip", "Test_venv").split()[1]
# Out:
# 1 version: June 6, 2023 Python 3.10.12
# 2 version: June 6, 2023 Python 3.11.4
# 3 version: June 6, 2023 Python 3.7.17
# 4 version: June 6, 2023 Python 3.8.17
# 5 version: June 6, 2023 Python 3.9.17
# 6 version: April 5, 2023 Python 3.10.11
# 7 version: April 5, 2023 Python 3.11.3
# 8 version: Feb. 8, 2023 Python 3.10.10
# 9 version: Feb. 8, 2023 Python 3.11.2
# 10 version: Dec. 6, 2022 Python 3.11.1
# 11 version: Dec. 6, 2022 Python 3.10.9
# 12 version: Dec. 6, 2022 Python 3.9.16
# 13 version: Dec. 6, 2022 Python 3.8.16
# 14 version: Dec. 6, 2022 Python 3.7.16
# 15 version: Oct. 24, 2022 Python 3.11.0
# 16 version: Oct. 11, 2022 Python 3.9.15
# 17 version: Oct. 11, 2022 Python 3.8.15
# 18 version: Oct. 11, 2022 Python 3.10.8
# 19 version: Oct. 11, 2022 Python 3.7.15
# 20 version: Sept. 6, 2022 Python 3.7.14
# 21 version: Sept. 6, 2022 Python 3.8.14
# 22 version: Sept. 6, 2022 Python 3.9.14
# 23 version: Sept. 6, 2022 Python 3.10.7
# 24 version: Aug. 2, 2022 Python 3.10.6
# 25 version: June 6, 2022 Python 3.10.5
# 26 version: May 17, 2022 Python 3.9.13
# 27 version: March 24, 2022 Python 3.10.4
# 28 version: March 23, 2022 Python 3.9.12
# 29 version: March 16, 2022 Python 3.10.3
# 30 version: March 16, 2022 Python 3.9.11
# 31 version: March 16, 2022 Python 3.8.13
# 32 version: March 16, 2022 Python 3.7.13
# 33 version: Jan. 14, 2022 Python 3.9.10
# 34 version: Jan. 14, 2022 Python 3.10.2
# 35 version: Dec. 6, 2021 Python 3.10.1
# 36 version: Nov. 15, 2021 Python 3.9.9
# 37 version: Nov. 5, 2021 Python 3.9.8
# 38 version: Oct. 4, 2021 Python 3.10.0
# 39 version: Sept. 4, 2021 Python 3.7.12
# 40 version: Sept. 4, 2021 Python 3.6.15
# 41 version: Aug. 30, 2021 Python 3.9.7
# 42 version: Aug. 30, 2021 Python 3.8.12
# 43 version: June 28, 2021 Python 3.9.6
# 44 version: June 28, 2021 Python 3.8.11
# 45 version: June 28, 2021 Python 3.6.14
# 46 version: June 28, 2021 Python 3.7.11
# 47 version: May 3, 2021 Python 3.9.5
# 48 version: May 3, 2021 Python 3.8.10
# 49 version: April 4, 2021 Python 3.9.4
# 50 version: April 2, 2021 Python 3.8.9
# 51 version: Feb. 19, 2021 Python 3.9.2
# 52 version: Feb. 19, 2021 Python 3.8.8
# 53 version: Feb. 15, 2021 Python 3.6.13
# 54 version: Feb. 15, 2021 Python 3.7.10
# 55 version: Dec. 21, 2020 Python 3.8.7
# 56 version: Dec. 7, 2020 Python 3.9.1
# 57 version: Oct. 5, 2020 Python 3.9.0
# 58 version: Sept. 24, 2020 Python 3.8.6
# 59 version: Sept. 5, 2020 Python 3.5.10
# 60 version: Aug. 17, 2020 Python 3.7.9
# 61 version: Aug. 17, 2020 Python 3.6.12
# 62 version: July 20, 2020 Python 3.8.5
# 63 version: July 13, 2020 Python 3.8.4
# 64 version: June 27, 2020 Python 3.7.8
# 65 version: June 27, 2020 Python 3.6.11
# 66 version: May 13, 2020 Python 3.8.3
# 67 version: April 20, 2020 Python 2.7.18
# 68 version: March 10, 2020 Python 3.7.7
# 69 version: Feb. 24, 2020 Python 3.8.2
# 70 version: Dec. 18, 2019 Python 3.8.1
# 71 version: Dec. 18, 2019 Python 3.7.6
# 72 version: Dec. 18, 2019 Python 3.6.10
# 73 version: Nov. 2, 2019 Python 3.5.9
# 74 version: Oct. 29, 2019 Python 3.5.8
# 75 version: Oct. 19, 2019 Python 2.7.17
# 76 version: Oct. 15, 2019 Python 3.7.5
# 77 version: Oct. 14, 2019 Python 3.8.0
# 78 version: July 8, 2019 Python 3.7.4
# 79 version: July 2, 2019 Python 3.6.9
# 80 version: March 25, 2019 Python 3.7.3
# 81 version: March 18, 2019 Python 3.4.10
# 82 version: March 18, 2019 Python 3.5.7
# 83 version: March 4, 2019 Python 2.7.16
# 84 version: Dec. 24, 2018 Python 3.7.2
# 85 version: Dec. 24, 2018 Python 3.6.8
# 86 version: Oct. 20, 2018 Python 3.7.1
# 87 version: Oct. 20, 2018 Python 3.6.7
# 88 version: Aug. 2, 2018 Python 3.5.6
# 89 version: Aug. 2, 2018 Python 3.4.9
# 90 version: June 27, 2018 Python 3.7.0
# 91 version: June 27, 2018 Python 3.6.6
# 92 version: May 1, 2018 Python 2.7.15
# 93 version: March 28, 2018 Python 3.6.5
# 94 version: Feb. 5, 2018 Python 3.4.8
# 95 version: Feb. 5, 2018 Python 3.5.5
# 96 version: Dec. 19, 2017 Python 3.6.4
# 97 version: Oct. 3, 2017 Python 3.6.3
# 98 version: Sept. 19, 2017 Python 3.3.7
# 99 version: Sept. 16, 2017 Python 2.7.14
# 100 version: Aug. 9, 2017 Python 3.4.7
# 101 version: Aug. 8, 2017 Python 3.5.4
# 102 version: July 17, 2017 Python 3.6.2
# 103 version: March 21, 2017 Python 3.6.1
# 104 version: Jan. 17, 2017 Python 3.4.6
# 105 version: Jan. 17, 2017 Python 3.5.3
# 106 version: Dec. 23, 2016 Python 3.6.0
# 107 version: Dec. 17, 2016 Python 2.7.13
# 108 version: June 27, 2016 Python 3.4.5
# 109 version: June 27, 2016 Python 3.5.2
# 110 version: June 25, 2016 Python 2.7.12
# 111 version: Dec. 21, 2015 Python 3.4.4
# 112 version: Dec. 7, 2015 Python 3.5.1
# 113 version: Dec. 5, 2015 Python 2.7.11
# 114 version: Sept. 13, 2015 Python 3.5.0
# 115 version: May 23, 2015 Python 2.7.10
# 116 version: Feb. 25, 2015 Python 3.4.3
# 117 version: Dec. 10, 2014 Python 2.7.9
# 118 version: Oct. 13, 2014 Python 3.4.2
# 119 version: Oct. 12, 2014 Python 3.3.6
# 120 version: Oct. 12, 2014 Python 3.2.6
# 121 version: July 2, 2014 Python 2.7.8
# 122 version: June 1, 2014 Python 2.7.7
# 123 version: May 19, 2014 Python 3.4.1
# 124 version: March 17, 2014 Python 3.4.0
# 125 version: March 9, 2014 Python 3.3.5
# 126 version: Feb. 9, 2014 Python 3.3.4
# 127 version: Nov. 17, 2013 Python 3.3.3
# 128 version: Nov. 10, 2013 Python 2.7.6
# 129 version: Oct. 29, 2013 Python 2.6.9
# 130 version: May 15, 2013 Python 3.3.2
# 131 version: May 15, 2013 Python 3.2.5
# 132 version: May 12, 2013 Python 2.7.5
# 133 version: April 6, 2013 Python 3.3.1
# 134 version: April 6, 2013 Python 3.2.4
# 135 version: April 6, 2013 Python 2.7.4
# 136 version: Sept. 29, 2012 Python 3.3.0
# 137 version: April 10, 2012 Python 3.2.3
# 138 version: April 10, 2012 Python 2.6.8
# 139 version: April 9, 2012 Python 2.7.3
# 140 version: April 9, 2012 Python 3.1.5
# 141 version: Sept. 3, 2011 Python 3.2.2
# 142 version: July 9, 2011 Python 3.2.1
# 143 version: June 11, 2011 Python 2.7.2
# 144 version: June 11, 2011 Python 3.1.4
# 145 version: June 3, 2011 Python 2.6.7
# 146 version: May 26, 2011 Python 2.5.6
# 147 version: Feb. 20, 2011 Python 3.2.0
# 148 version: Nov. 27, 2010 Python 3.1.3
# 149 version: Nov. 27, 2010 Python 2.7.1
# 150 version: Aug. 24, 2010 Python 2.6.6
# 151 version: July 3, 2010 Python 2.7.0
# 152 version: March 20, 2010 Python 3.1.2
# 153 version: March 18, 2010 Python 2.6.5
# 154 version: Jan. 31, 2010 Python 2.5.5
# 155 version: Oct. 26, 2009 Python 2.6.4
# 156 version: Oct. 2, 2009 Python 2.6.3
# 157 version: Aug. 17, 2009 Python 3.1.1
# 158 version: June 26, 2009 Python 3.1.0
# 159 version: April 14, 2009 Python 2.6.2
# 160 version: Feb. 13, 2009 Python 3.0.1
# 161 version: Dec. 23, 2008 Python 2.5.4
# 162 version: Dec. 19, 2008 Python 2.4.6
# 163 version: Dec. 19, 2008 Python 2.5.3
# 164 version: Dec. 4, 2008 Python 2.6.1
# 165 version: Dec. 3, 2008 Python 3.0.0
# 166 version: Oct. 2, 2008 Python 2.6.0
# 167 version: March 11, 2008 Python 2.3.7
# 168 version: March 11, 2008 Python 2.4.5
# 169 version: Feb. 21, 2008 Python 2.5.2
# 170 version: April 19, 2007 Python 2.5.1
# 171 version: Nov. 1, 2006 Python 2.3.6
# 172 version: Oct. 18, 2006 Python 2.4.4
# 173 version: Sept. 19, 2006 Python 2.5.0
# 174 version: April 15, 2006 Python 2.4.3
# 175 version: Sept. 27, 2005 Python 2.4.2
# 176 version: March 30, 2005 Python 2.4.1
# 177 version: Feb. 8, 2005 Python 2.3.5
# 178 version: Nov. 30, 2004 Python 2.4.0
# 179 version: May 27, 2004 Python 2.3.4
# 180 version: Dec. 19, 2003 Python 2.3.3
# 181 version: Oct. 3, 2003 Python 2.3.2
# 182 version: Sept. 23, 2003 Python 2.3.1
# 183 version: July 29, 2003 Python 2.3.0
# 184 version: May 30, 2003 Python 2.2.3
# 185 version: Oct. 14, 2002 Python 2.2.2
# 186 version: April 10, 2002 Python 2.2.1
# 187 version: April 9, 2002 Python 2.1.3
# 188 version: Dec. 21, 2001 Python 2.2.0
# 189 version: June 22, 2001 Python 2.0.1

# %%
def create_env_with_base_pkgs(env_name: str, python_version: str) -> None:
    {"""
    Creates a new conda environment with the same packages as the base environment,
    but with a different Python version.

    Args:
        env_name (str): The name of the new environment.
        python_version (str): The version of Python to use in the new environment.
    """}
    # Get a list of all the packages installed in the base environment
    pkgs = subprocess.check_output(["conda", "list", "--json"]).decode("utf-8")
    pkgs = json.loads(pkgs)["packages"]
    pkgs = [pkg["name"] for pkg in pkgs]

    # Create a new environment with the same packages as the base environment
    cmd = ["conda", "create", "-n", env_name, "--clone", "base", "--no-default-packages"]
    cmd += ["--override-channels", "--channel", "defaults"]
    cmd += ["python=" + python_version] + pkgs
    subprocess.run(cmd, check=True)

create_env_with_base_pkgs("3.10.12-base", version)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 23
#      20     cmd += ["python=" + python_version] + pkgs
#      21     subprocess.run(cmd, check=True)
# ---> 23 create_env_with_base_pkgs("3.10.12-base", version)
#
# Cell In[44], line 14, in create_env_with_base_pkgs(env_name, python_version)
#      12 # Get a list of all the packages installed in the base environment
#      13 pkgs = subprocess.check_output(["conda", "list", "--json"]).decode("utf-8")
# ---> 14 pkgs = json.loads(pkgs)["packages"]
#      15 pkgs = [pkg["name"] for pkg in pkgs]
#      17 # Create a new environment with the same packages as the base environment
#
# TypeError: list indices must be integers or slices, not str
